# %%
# Enable interactive plots
# %matplotlib ipympl

import numpy as np
import pandas as pd
from astropy.io import fits
from astropy.table import Table

from dysh.log import init_logging
from dysh.fits.gbtfitsload import GBTFITSLoad, GBTOffline, GBTOnline
from dysh.util.files import dysh_data

init_logging(2)

# %%
# fake spectrum
from dysh.spectra.spectrum import Spectrum
sp = Spectrum.fake_spectrum(seed=123)
sp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# position-switch observation
sdf = GBTFITSLoad(dysh_data(test="getps"))
sb = sdf.getps(ifnum=0, plnum=0, fdnum=0)
sb.plot()  # .write("getps.fits", avechan=8, overwrite=True)
sp = sb.timeaverage()
sp.smooth('box',31).plot()
# Out:
# /home/teuben/GBT/dyshp/anaconda3/lib/python3.12/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# /home/teuben/GBT/dyshp/anaconda3/lib/python3.12/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
